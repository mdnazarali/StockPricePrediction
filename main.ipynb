# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
import yfinance as yf

tickerData = yf.Ticker('SBIN.NS')
df = tickerData.history(period='1d', start='2010-1-1', end='2023-10-25')
df.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-01-04 00:00:00+05:30  194.332934  196.468461  194.332934  195.716751
# 2010-01-05 00:00:00+05:30  197.151881  197.322720  194.768625  195.789413
# 2010-01-06 00:00:00+05:30  196.212249  197.749831  195.187198  196.963959
# 2010-01-07 00:00:00+05:30  196.981027  197.322706  194.854037  195.862000
# 2010-01-08 00:00:00+05:30  195.955967  196.801640  194.768614  195.276871
#
#                              Volume  Dividends  Stock Splits
# Date
# 2010-01-04 00:00:00+05:30  11031470        0.0           0.0
# 2010-01-05 00:00:00+05:30  11613740        0.0           0.0
# 2010-01-06 00:00:00+05:30  14527930        0.0           0.0
# 2010-01-07 00:00:00+05:30   8576510        0.0           0.0
# 2010-01-08 00:00:00+05:30  10453820        0.0           0.0

# %%
df.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-10-17 00:00:00+05:30  577.700012  579.950012  575.299988  576.450012
# 2023-10-18 00:00:00+05:30  577.750000  579.250000  569.349976  572.650024
# 2023-10-19 00:00:00+05:30  569.799988  574.000000  567.000000  571.200012
# 2023-10-20 00:00:00+05:30  569.900024  570.000000  562.099976  563.099976
# 2023-10-23 00:00:00+05:30  563.099976  566.000000  551.000000  552.950012
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-10-17 00:00:00+05:30  10765224        0.0           0.0
# 2023-10-18 00:00:00+05:30  11777454        0.0           0.0
# 2023-10-19 00:00:00+05:30  11441499        0.0           0.0
# 2023-10-20 00:00:00+05:30  11110988        0.0           0.0
# 2023-10-23 00:00:00+05:30  11875035        0.0           0.0

# %%
df = df.reset_index() 
df.head()
# Out:
#                        Date        Open        High         Low       Close  \
# 0 2010-01-04 00:00:00+05:30  194.332934  196.468461  194.332934  195.716751
# 1 2010-01-05 00:00:00+05:30  197.151881  197.322720  194.768625  195.789413
# 2 2010-01-06 00:00:00+05:30  196.212249  197.749831  195.187198  196.963959
# 3 2010-01-07 00:00:00+05:30  196.981027  197.322706  194.854037  195.862000
# 4 2010-01-08 00:00:00+05:30  195.955967  196.801640  194.768614  195.276871
#
#      Volume  Dividends  Stock Splits
# 0  11031470        0.0           0.0
# 1  11613740        0.0           0.0
# 2  14527930        0.0           0.0
# 3   8576510        0.0           0.0
# 4  10453820        0.0           0.0

# %%
df = df.drop(['Date', 'Dividends', 'Stock Splits', 'Volume'], axis = 1)
df.head()
# Out:
#          Open        High         Low       Close
# 0  194.332934  196.468461  194.332934  195.716751
# 1  197.151881  197.322720  194.768625  195.789413
# 2  196.212249  197.749831  195.187198  196.963959
# 3  196.981027  197.322706  194.854037  195.862000
# 4  195.955967  196.801640  194.768614  195.276871

# %%
plt.plot(df.Close)

# %%
plt.plot(df.Open)

# %%
df
# Out:
#             Open        High         Low       Close
# 0     194.332964  196.468491  194.332964  195.716782
# 1     197.151819  197.322659  194.768564  195.789352
# 2     196.212234  197.749816  195.187183  196.963943
# 3     196.981011  197.322690  194.854022  195.861984
# 4     195.955936  196.801609  194.768584  195.276840
# ...          ...         ...         ...         ...
# 3404  577.700012  579.950012  575.299988  576.450012
# 3405  577.750000  579.250000  569.349976  572.650024
# 3406  569.799988  574.000000  567.000000  571.200012
# 3407  569.900024  570.000000  562.099976  563.099976
# 3408  563.099976  566.000000  551.000000  552.950012
#
# [3409 rows x 4 columns]

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 3404    584.327077
# 3405    584.351876
# 3406    584.315580
# 3407    584.109999
# 3408    583.824500
# Name: Close, Length: 3409, dtype: float64

# %%
maO100 = df.Open.rolling(100).mean()
maO100
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 3404    585.200876
# 3405    585.269317
# 3406    585.265616
# 3407    585.177082
# 3408    584.971501
# Name: Open, Length: 3409, dtype: float64

# %%
plt.figure(figsize =(12,6))
plt.plot(df.Close)
plt.plot(ma100, 'g')
plt.plot(maO100, 'r')

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 2527    133.535923
# 2528    133.769484
# 2529    133.996651
# 2530    134.228552
# 2531    134.455447
# Name: Close, Length: 2532, dtype: float64

# %%
plt.figure(figsize =(12,6))
plt.plot(df.Close)
plt.plot(ma100, 'g')
plt.plot(ma200, 'r')

# %%
df.shape
# Out:
# (3409, 4)

# %%
data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (2386, 1)
# (1023, 1)

# %%
data_training.head()
# Out:
#         Close
# 0  195.716782
# 1  195.789352
# 2  196.963943
# 3  195.861984
# 4  195.276840

# %%
data_testing.head()
# Out:
#            Close
# 2386  266.053955
# 2387  272.992432
# 2388  274.715088
# 2389  279.165283
# 2390  272.466064

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.27669853],
#        [0.27702521],
#        [0.28231261],
#        ...,
#        [0.58082702],
#        [0.57307237],
#        [0.57587275]])

# %%
data_training_array.shape
# Out:
# (2386, 1)

# %%
x_train = []
y_train = []
for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2286, 100, 1)

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))
model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))
model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.5))

model.add(Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 100, 50)           10400
#
#  dropout_4 (Dropout)         (None, 100, 50)           0
#
#  lstm_5 (LSTM)               (None, 100, 60)           26640
#
#  dropout_5 (Dropout)         (None, 100, 60)           0
#
#  lstm_6 (LSTM)               (None, 100, 80)           45120
#
#  dropout_6 (Dropout)         (None, 100, 80)           0
#
#  lstm_7 (LSTM)               (None, 100, 60)           33840
#
#  dropout_7 (Dropout)         (None, 100, 60)           0
#
#  dense_1 (Dense)             (None, 100, 1)            61
#
# =================================================================
# Total params: 116061 (453.36 KB)
# Trainable params: 116061 (453.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(Optimizer='adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# WARNING:tensorflow:From C:\Users\imdna\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\imdna\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 72/72 [==============================] - 28s 274ms/step - loss: 0.0695
# Epoch 2/50
# 72/72 [==============================] - 19s 270ms/step - loss: 0.0521
# Epoch 3/50
# 72/72 [==============================] - 19s 269ms/step - loss: 0.0507
# Epoch 4/50
# 72/72 [==============================] - 19s 265ms/step - loss: 0.0496
# Epoch 5/50
# 72/72 [==============================] - 19s 266ms/step - loss: 0.0490
# Epoch 6/50
# 72/72 [==============================] - 19s 266ms/step - loss: 0.0485
# Epoch 7/50
# 72/72 [==============================] - 19s 268ms/step - loss: 0.0479
# Epoch 8/50
# 72/72 [==============================] - 19s 266ms/step - loss: 0.0476
# Epoch 9/50
# 72/72 [==============================] - 19s 266ms/step - loss: 0.